# %%
a = "Rahul is a smart boy"
print(a)
# Out:
# Rahul is a smart boy

# %%
b = "Tournament of power"
print(b)
b = "Dragon ball"
print(b)
# Out:
# Tournament of power
# Dragon ball

# %%
b = "Hi Devansh, kal ka match dekhna"
print(b)
# Out:
# Hi Devansh, kal ka match dekhna

# %%
print("Christine Caine once said:","Sometimes when you're in a dark place you think you've been buried,but you've actually been planted")
# Out:
# Christine Caine once said: Sometimes when you're in a dark place you think you've been buried,but you've actually been planted

# %%
famous_person = "Christine Caine"
message = f"{famous_person} once said:,Sometimes when you're in a dark place you think you've been buried,but you've actually been planted"
print(message)
# Out:
# Christine Caine once said:,Sometimes when you're in a dark place you think you've been buried,but you've actually been planted

# %%
print(10-2)
print(16/2)
print(6+2)
print(2*4)
# Out:
# 8
# 8.0
# 8
# 8

# %%
c = 25
print(f"My favourite number is {c}")
# Out:
# My favourite number is 25

# %%
# Name: Rahul
# Date: 24-02-2026
# This program stores a favourite number and prints it.

a = 25
print(f"This is my favourite number {a}")
# Out:
# This is my favourite number 25

# %%
# Name: Rahul
# Date: 24-02-2026
# This program prints the name of each person in the list.

names = ["Rahul", "Amit", "Neha", "Priya"]

print(f"{names[0]}")
print(f"{names[1]}")
print(f"{names[2]}")
print(f"{names[3]}")
# Out:
# Rahul
# Amit
# Neha
# Priya

# %%
b = ["Rahul","Devansh","Ayush","Harsh"]
print(b[0])
print(b[1])
print(b[2])
print(b[3])
# Out:
# Rahul
# Devansh
# Ayush
# Harsh

# %%
print(f"Hello {b[0]} kaisa ha bhai tu")
print(f"Hello {b[1]} kaisa ha bhai tu")
print(f"Hello {b[2]} kaisa ha bhai tu")
print(f"Hello {b[3]} kaisa ha bhai tu")
# Out:
# Hello Rahul kaisa ha bhai tu
# Hello Devansh kaisa ha bhai tu
# Hello Ayush kaisa ha bhai tu
# Hello Harsh kaisa ha bhai tu

# %%
cars = ["Honda", "BMW", "Audi", "Tesla"]

print(f"I would like to own a {cars[0]} car.")
print(f"I would like to own a {cars[1]} car.")
print(f"I would like to own a {cars[2]} car.")
print(f"I would like to own a {cars[3]} car.")
# Out:
# I would like to own a Honda car.
# I would like to own a BMW car.
# I would like to own a Audi car.
# I would like to own a Tesla car.
